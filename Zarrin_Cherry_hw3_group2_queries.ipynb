-- %% [markdown]
-- /\* =========================================================
--
--    Name: Zarrin Cherry
--
--    Course: CSCI 331 - Database Systems
--
--    Project 3 - Chapter 3 SQL Queries
--
--    Database: WideWorldImporters (via Docker + DBeaver)
--
--    Note: Each query below includes a comment describing
--
--          the proposition and the type of JOIN used.
--
--    ========================================================= \*/

-- %% [markdown]
-- Q1. Proposition: List a small sample of customers with their category names.
--
-- Join type: INNER JOIN (Customers → CustomerCategories)
--
-- \========================================================= \*/

-- %%
SELECT TOP (10)
       c.CustomerID,             -- customer unique ID
       c.CustomerName,           -- customer name
       cc.CustomerCategoryName   -- category name from CustomerCategories table
FROM Sales.Customers AS c        -- Customers table (alias = c)
INNER JOIN Sales.CustomerCategories AS cc               -- join to categories
  ON cc.CustomerCategoryID = c.CustomerCategoryID       -- match category IDs
ORDER BY c.CustomerID;           -- sort by customer ID
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.045
-- <table><tr><th>CustomerID</th><th>CustomerName</th><th>CustomerCategoryName</th></tr><tr><td>1</td><td>Tailspin Toys (Head Office)</td><td>Novelty Shop</td></tr><tr><td>2</td><td>Tailspin Toys (Sylvanite, MT)</td><td>Novelty Shop</td></tr><tr><td>3</td><td>Tailspin Toys (Peeples Valley, AZ)</td><td>Novelty Shop</td></tr><tr><td>4</td><td>Tailspin Toys (Medicine Lodge, KS)</td><td>Novelty Shop</td></tr><tr><td>5</td><td>Tailspin Toys (Gasport, NY)</td><td>Novelty Shop</td></tr><tr><td>6</td><td>Tailspin Toys (Jessie, ND)</td><td>Novelty Shop</td></tr><tr><td>7</td><td>Tailspin Toys (Frankewing, TN)</td><td>Novelty Shop</td></tr><tr><td>8</td><td>Tailspin Toys (Bow Mar, CO)</td><td>Novelty Shop</td></tr><tr><td>9</td><td>Tailspin Toys (Netcong, NJ)</td><td>Novelty Shop</td></tr><tr><td>10</td><td>Tailspin Toys (Wimbledon, ND)</td><td>Novelty Shop</td></tr></table>

-- %% [markdown]
-- /\* =========================================================
--
-- Q2. Proposition: Show every customer category and how many customers are in each.
--
-- Join type: LEFT OUTER JOIN (preserve all categories, even with 0 customers)
--
-- \========================================================= \*/

-- %%
SELECT cc.CustomerCategoryID,           -- category ID
       cc.CustomerCategoryName,         -- category name
       COUNT(c.CustomerID) AS CustomersInCategory      -- number of customers in each category
FROM Sales.CustomerCategories AS cc                    -- base table for categories
LEFT JOIN Sales.Customers AS c          -- join customers to categories
  ON c.CustomerCategoryID = cc.CustomerCategoryID
GROUP BY cc.CustomerCategoryID, cc.CustomerCategoryName    -- group by category
ORDER BY cc.CustomerCategoryID;         -- order by ID for readability
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.020
-- <table><tr><th>CustomerCategoryID</th><th>CustomerCategoryName</th><th>CustomersInCategory</th></tr><tr><td>1</td><td>Agent</td><td>0</td></tr><tr><td>2</td><td>Wholesaler</td><td>0</td></tr><tr><td>3</td><td>Novelty Shop</td><td>459</td></tr><tr><td>4</td><td>Supermarket</td><td>58</td></tr><tr><td>5</td><td>Computer Store</td><td>51</td></tr><tr><td>6</td><td>Gift Store</td><td>48</td></tr><tr><td>7</td><td>Corporate</td><td>47</td></tr><tr><td>8</td><td>General Retailer</td><td>0</td></tr></table>

-- %% [markdown]
-- /\* =========================================================
--
--  Q3. Proposition: Find customers with a missing WebsiteURL,
--
--    include their total number of orders, and flag who is missing.
--
--    Join type: LEFT OUTER JOIN (customers preserved) \*/

-- %%
SELECT
    c.CustomerID,            -- customer ID
    c.CustomerName,          -- customer name
    c.WebsiteURL,            -- website URL (may be missing)
    CASE
        WHEN c.WebsiteURL IS NULL OR LTRIM(RTRIM(c.WebsiteURL)) = '' THEN 1
        ELSE 0
    END AS IsMissingWebsite,           -- flag if website is missing (1 = missing)
    COUNT(o.OrderID) AS TotalOrders    -- total number of orders for that customer
FROM Sales.Customers AS c
LEFT JOIN Sales.Orders AS o
  ON o.CustomerID = c.CustomerID       -- match customers to orders
GROUP BY
    c.CustomerID, c.CustomerName, c.WebsiteURL,
    CASE
        WHEN c.WebsiteURL IS NULL OR LTRIM(RTRIM(c.WebsiteURL)) = '' THEN 1
        ELSE 0
    END
ORDER BY IsMissingWebsite DESC, TotalOrders DESC, c.CustomerID;
-- Out:
-- (663 rows affected)
-- Total execution time: 00:00:00.072
-- <table><tr><th>CustomerID</th><th>CustomerName</th><th>WebsiteURL</th><th>IsMissingWebsite</th><th>TotalOrders</th></tr><tr><td>90</td><td>Tailspin Toys (Tolna, ND)</td><td>http://www.tailspintoys.com/Tolna</td><td>0</td><td>150</td></tr><tr><td>831</td><td>Bhaavan Rai</td><td>http://www.microsoft.com/BhaavanRai/</td><td>0</td><td>147</td></tr><tr><td>968</td><td>Anca Gogean</td><td>http://www.microsoft.com/AncaGogean/</td><td>0</td><td>146</td></tr><tr><td>405</td><td>Wingtip Toys (Bourbonnais, IL)</td><td>http://www.wingtiptoys.com/Bourbonnais</td><td>0</td><td>145</td></tr><tr><td>804</td><td>Aleksandrs Riekstins</td><td>http://www.microsoft.com/AleksandrsRiekstins/</td><td>0</td><td>145</td></tr><tr><td>70</td><td>Tailspin Toys (New Baden, IL)</td><td>http://www.tailspintoys.com/NewBaden</td><td>0</td><td>144</td></tr><tr><td>143</td><td>Tailspin Toys (Ashtabula, OH)</td><td>http://www.tailspintoys.com/Ashtabula</td><td>0</td><td>144</td></tr><tr><td>110</td><td>Tailspin Toys (North Crows Nest, IN)</td><td>http://www.tailspintoys.com/NorthCrowsNest</td><td>0</td><td>143</td></tr><tr><td>183</td><td>Tailspin Toys (Tierra Verde, FL)</td><td>http://www.tailspintoys.com/TierraVerde</td><td>0</td><td>141</td></tr><tr><td>580</td><td>Wingtip Toys (Sarversville, PA)</td><td>http://www.wingtiptoys.com/Sarversville</td><td>0</td><td>140</td></tr><tr><td>598</td><td>Wingtip Toys (Kapa&#39;a, HI)</td><td>http://www.wingtiptoys.com/Kapa&#39;a</td><td>0</td><td>140</td></tr><tr><td>910</td><td>Elina Kaleja</td><td>http://www.microsoft.com/ElinaKaleja/</td><td>0</td><td>140</td></tr><tr><td>964</td><td>Ingrida Zeltina</td><td>http://www.microsoft.com/IngridaZeltina/</td><td>0</td><td>140</td></tr><tr><td>32</td><td>Tailspin Toys (Maypearl, TX)</td><td>http://www.tailspintoys.com/Maypearl</td><td>0</td><td>139</td></tr><tr><td>67</td><td>Tailspin Toys (Sentinel Butte, ND)</td><td>http://www.tailspintoys.com/SentinelButte</td><td>0</td><td>139</td></tr><tr><td>941</td><td>Bishwa Chatterjee</td><td>http://www.microsoft.com/BishwaChatterjee/</td><td>0</td><td>139</td></tr><tr><td>16</td><td>Tailspin Toys (Coney Island, MO)</td><td>http://www.tailspintoys.com/ConeyIsland</td><td>0</td><td>138</td></tr><tr><td>569</td><td>Wingtip Toys (West Frostproof, FL)</td><td>http://www.wingtiptoys.com/WestFrostproof</td><td>0</td><td>138</td></tr><tr><td>930</td><td>Shantanu Huq</td><td>http://www.microsoft.com/ShantanuHuq/</td><td>0</td><td>138</td></tr><tr><td>493</td><td>Wingtip Toys (Federalsburg, MD)</td><td>http://www.wingtiptoys.com/Federalsburg</td><td>0</td><td>137</td></tr><tr><td>558</td><td>Wingtip Toys (Bourneville, OH)</td><td>http://www.wingtiptoys.com/Bourneville</td><td>0</td><td>137</td></tr><tr><td>975</td><td>Prabodh Nair</td><td>http://www.microsoft.com/PrabodhNair/</td><td>0</td><td>137</td></tr><tr><td>980</td><td>Om Yadav</td><td>http://www.microsoft.com/OmYadav/</td><td>0</td><td>137</td></tr><tr><td>35</td><td>Tailspin Toys (Slanesville, WV)</td><td>http://www.tailspintoys.com/Slanesville</td><td>0</td><td>136</td></tr><tr><td>516</td><td>Wingtip Toys (Harkers Island, NC)</td><td>http://www.wingtiptoys.com/HarkersIsland</td><td>0</td><td>136</td></tr><tr><td>546</td><td>Wingtip Toys (Key Biscayne, FL)</td><td>http://www.wingtiptoys.com/KeyBiscayne</td><td>0</td><td>136</td></tr><tr><td>906</td><td>Ajitaab Pakalapati</td><td>http://www.microsoft.com/AjitaabPakalapati/</td><td>0</td><td>136</td></tr><tr><td>102</td><td>Tailspin Toys (Fieldbrook, CA)</td><td>http://www.tailspintoys.com/Fieldbrook</td><td>0</td><td>135</td></tr><tr><td>185</td><td>Tailspin Toys (Vidrine, LA)</td><td>http://www.tailspintoys.com/Vidrine</td><td>0</td><td>135</td></tr><tr><td>448</td><td>Wingtip Toys (Salt Wells, NV)</td><td>http://www.wingtiptoys.com/SaltWells</td><td>0</td><td>135</td></tr><tr><td>7</td><td>Tailspin Toys (Frankewing, TN)</td><td>http://www.tailspintoys.com/Frankewing</td><td>0</td><td>133</td></tr><tr><td>38</td><td>Tailspin Toys (A ...

-- %% [markdown]
-- /\* =========================================================
--
-- Q4. Proposition: List customers with bad phone numbers,
--
--    show their delivery country, and flag bad ones.
--
--    Join type: INNER JOIN chain (Customers → Cities → States → Countries) \*/

-- %%
SELECT
    c.CustomerID,              -- customer ID
    c.CustomerName,            -- customer name
    c.PhoneNumber,             -- phone number
    co.CountryName,            -- country name
    CASE
        WHEN c.PhoneNumber IS NULL
             OR c.PhoneNumber IN ('', 'N/A', '000-000-0000')
        THEN 1 ELSE 0
    END AS IsBadPhone          -- flag if phone is invalid
FROM Sales.Customers AS c
INNER JOIN Application.Cities AS ci
  ON ci.CityID = c.DeliveryCityID
INNER JOIN Application.StateProvinces AS sp
  ON sp.StateProvinceID = ci.StateProvinceID
INNER JOIN Application.Countries AS co
  ON co.CountryID = sp.CountryID
ORDER BY IsBadPhone DESC, c.CustomerID;
-- Out:
-- (663 rows affected)
-- Total execution time: 00:00:00.031
-- <table><tr><th>CustomerID</th><th>CustomerName</th><th>PhoneNumber</th><th>CountryName</th><th>IsBadPhone</th></tr><tr><td>1</td><td>Tailspin Toys (Head Office)</td><td>(308) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>2</td><td>Tailspin Toys (Sylvanite, MT)</td><td>(406) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>3</td><td>Tailspin Toys (Peeples Valley, AZ)</td><td>(480) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>4</td><td>Tailspin Toys (Medicine Lodge, KS)</td><td>(316) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>5</td><td>Tailspin Toys (Gasport, NY)</td><td>(212) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>6</td><td>Tailspin Toys (Jessie, ND)</td><td>(701) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>7</td><td>Tailspin Toys (Frankewing, TN)</td><td>(423) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>8</td><td>Tailspin Toys (Bow Mar, CO)</td><td>(303) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>9</td><td>Tailspin Toys (Netcong, NJ)</td><td>(201) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>10</td><td>Tailspin Toys (Wimbledon, ND)</td><td>(701) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>11</td><td>Tailspin Toys (Devault, PA)</td><td>(215) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>12</td><td>Tailspin Toys (Biscay, MN)</td><td>(218) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>13</td><td>Tailspin Toys (Stonefort, IL)</td><td>(217) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>14</td><td>Tailspin Toys (Long Meadow, MD)</td><td>(240) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>15</td><td>Tailspin Toys (Batson, TX)</td><td>(210) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>16</td><td>Tailspin Toys (Coney Island, MO)</td><td>(314) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>17</td><td>Tailspin Toys (East Fultonham, OH)</td><td>(216) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>18</td><td>Tailspin Toys (Goffstown, NH)</td><td>(603) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>19</td><td>Tailspin Toys (Lemeta, AK)</td><td>(907) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>20</td><td>Tailspin Toys (College Place, WA)</td><td>(206) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>21</td><td>Tailspin Toys (Tresckow, PA)</td><td>(215) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>22</td><td>Tailspin Toys (Ward Ridge, FL)</td><td>(239) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>23</td><td>Tailspin Toys (Ikatan, AK)</td><td>(907) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>24</td><td>Tailspin Toys (Dundarrach, NC)</td><td>(252) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>25</td><td>Tailspin Toys (Avenal, CA)</td><td>(209) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>26</td><td>Tailspin Toys (Hedrick, IA)</td><td>(319) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>27</td><td>Tailspin Toys (Bowlus, MN)</td><td>(218) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>28</td><td>Tailspin Toys (North Ridge, NY)</td><td>(212) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>29</td><td>Tailspin Toys (Eulaton, AL)</td><td>(205) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>30</td><td>Tailspin Toys (Koontzville, WA)</td><td>(206) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>31</td><td>Tailspin Toys (Lake Stevens, WA)</td><td>(206) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>32</td><td>Tailspin Toys (Maypearl, TX)</td><td>(210) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>33</td><td>Tailspin Toys (Boyden Arbor, SC)</td><td>(803) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>34</td><td>Tailspin Toys (Dallardsville, TX)</td><td>(210) 555-0100</td><td>United States</td><td>0</td></tr><tr><td>35</td><td>Tailspin Toys (Slanesville, W ...

-- %% [markdown]
-- /\* =========================================================
--
-- Q5. Proposition: Show the 15 newest customers and their MOST RECENT order date (if any).
--
-- Join type: LEFT OUTER JOIN (keep customers with zero orders)
--
-- \========================================================= \*/

-- %%
SELECT TOP (15)
       c.CustomerID,              -- customer ID
       c.CustomerName,            -- customer name
       c.AccountOpenedDate,       -- account creation date
       MAX(o.OrderDate) AS LastOrderDate                   -- most recent order date (if any)
FROM Sales.Customers AS c
LEFT JOIN Sales.Orders AS o
  ON o.CustomerID = c.CustomerID
GROUP BY c.CustomerID, c.CustomerName, c.AccountOpenedDate
ORDER BY c.AccountOpenedDate DESC, c.CustomerID;           -- newest first
-- Out:
-- (15 rows affected)
-- Total execution time: 00:00:00.039
-- <table><tr><th>CustomerID</th><th>CustomerName</th><th>AccountOpenedDate</th><th>LastOrderDate</th></tr><tr><td>1061</td><td>Agrita Abele</td><td>2016-05-07</td><td>2016-05-27</td></tr><tr><td>1060</td><td>Anand Mudaliyar</td><td>2016-04-23</td><td>2016-05-24</td></tr><tr><td>1059</td><td>Jibek Juniskyzy</td><td>2016-03-13</td><td>2016-05-30</td></tr><tr><td>1058</td><td>Jaroslav Fisar</td><td>2016-02-01</td><td>2016-05-26</td></tr><tr><td>1057</td><td>Ganesh Majumdar</td><td>2016-01-09</td><td>2016-05-27</td></tr><tr><td>1056</td><td>Kalyani Benjaree</td><td>2015-12-20</td><td>2016-05-18</td></tr><tr><td>1055</td><td>Adriana Pena</td><td>2015-11-30</td><td>2016-05-27</td></tr><tr><td>1054</td><td>Emma Salpa</td><td>2015-11-29</td><td>2016-05-30</td></tr><tr><td>1053</td><td>Luis Saucedo</td><td>2015-11-27</td><td>2016-05-31</td></tr><tr><td>1052</td><td>Ian Olofsson</td><td>2015-09-26</td><td>2016-05-27</td></tr><tr><td>1051</td><td>Sylvie Laramee</td><td>2015-09-24</td><td>2016-05-28</td></tr><tr><td>1050</td><td>Amrita Ganguly</td><td>2015-09-23</td><td>2016-05-14</td></tr><tr><td>1049</td><td>Amet Shergill</td><td>2015-08-13</td><td>2016-05-11</td></tr><tr><td>1048</td><td>Abhra Ganguly</td><td>2015-08-09</td><td>2016-05-27</td></tr><tr><td>1047</td><td>Ivana Hadrabova</td><td>2015-07-28</td><td>2016-05-25</td></tr></table>

-- %% [markdown]
-- /\* =========================================================
--
-- Q6. Proposition: List all customers, show credit hold status,
--
-- and how many orders they have.
--
-- Join type: LEFT OUTER JOIN (customers preserved)
--
-- \*/

-- %%
SELECT 
    c.CustomerID,           -- customer ID
    c.CustomerName,         -- customer name
    CASE 
        WHEN c.IsOnCreditHold = 1 THEN 'On Hold'
        ELSE 'Clear'
    END AS CreditStatus,                   -- status based on IsOnCreditHold flag
    COUNT(o.OrderID) AS TotalOrders        -- number of orders placed
FROM Sales.Customers AS c
LEFT JOIN Sales.Orders AS o
    ON o.CustomerID = c.CustomerID
GROUP BY c.CustomerID, c.CustomerName, c.IsOnCreditHold
ORDER BY c.IsOnCreditHold DESC, TotalOrders DESC, c.CustomerID;
-- Out:
-- (663 rows affected)
-- Total execution time: 00:00:00.024
-- <table><tr><th>CustomerID</th><th>CustomerName</th><th>CreditStatus</th><th>TotalOrders</th></tr><tr><td>90</td><td>Tailspin Toys (Tolna, ND)</td><td>Clear</td><td>150</td></tr><tr><td>831</td><td>Bhaavan Rai</td><td>Clear</td><td>147</td></tr><tr><td>968</td><td>Anca Gogean</td><td>Clear</td><td>146</td></tr><tr><td>405</td><td>Wingtip Toys (Bourbonnais, IL)</td><td>Clear</td><td>145</td></tr><tr><td>804</td><td>Aleksandrs Riekstins</td><td>Clear</td><td>145</td></tr><tr><td>70</td><td>Tailspin Toys (New Baden, IL)</td><td>Clear</td><td>144</td></tr><tr><td>143</td><td>Tailspin Toys (Ashtabula, OH)</td><td>Clear</td><td>144</td></tr><tr><td>110</td><td>Tailspin Toys (North Crows Nest, IN)</td><td>Clear</td><td>143</td></tr><tr><td>183</td><td>Tailspin Toys (Tierra Verde, FL)</td><td>Clear</td><td>141</td></tr><tr><td>580</td><td>Wingtip Toys (Sarversville, PA)</td><td>Clear</td><td>140</td></tr><tr><td>598</td><td>Wingtip Toys (Kapa&#39;a, HI)</td><td>Clear</td><td>140</td></tr><tr><td>910</td><td>Elina Kaleja</td><td>Clear</td><td>140</td></tr><tr><td>964</td><td>Ingrida Zeltina</td><td>Clear</td><td>140</td></tr><tr><td>32</td><td>Tailspin Toys (Maypearl, TX)</td><td>Clear</td><td>139</td></tr><tr><td>67</td><td>Tailspin Toys (Sentinel Butte, ND)</td><td>Clear</td><td>139</td></tr><tr><td>941</td><td>Bishwa Chatterjee</td><td>Clear</td><td>139</td></tr><tr><td>16</td><td>Tailspin Toys (Coney Island, MO)</td><td>Clear</td><td>138</td></tr><tr><td>569</td><td>Wingtip Toys (West Frostproof, FL)</td><td>Clear</td><td>138</td></tr><tr><td>930</td><td>Shantanu Huq</td><td>Clear</td><td>138</td></tr><tr><td>493</td><td>Wingtip Toys (Federalsburg, MD)</td><td>Clear</td><td>137</td></tr><tr><td>558</td><td>Wingtip Toys (Bourneville, OH)</td><td>Clear</td><td>137</td></tr><tr><td>975</td><td>Prabodh Nair</td><td>Clear</td><td>137</td></tr><tr><td>980</td><td>Om Yadav</td><td>Clear</td><td>137</td></tr><tr><td>35</td><td>Tailspin Toys (Slanesville, WV)</td><td>Clear</td><td>136</td></tr><tr><td>516</td><td>Wingtip Toys (Harkers Island, NC)</td><td>Clear</td><td>136</td></tr><tr><td>546</td><td>Wingtip Toys (Key Biscayne, FL)</td><td>Clear</td><td>136</td></tr><tr><td>906</td><td>Ajitaab Pakalapati</td><td>Clear</td><td>136</td></tr><tr><td>102</td><td>Tailspin Toys (Fieldbrook, CA)</td><td>Clear</td><td>135</td></tr><tr><td>185</td><td>Tailspin Toys (Vidrine, LA)</td><td>Clear</td><td>135</td></tr><tr><td>448</td><td>Wingtip Toys (Salt Wells, NV)</td><td>Clear</td><td>135</td></tr><tr><td>7</td><td>Tailspin Toys (Frankewing, TN)</td><td>Clear</td><td>133</td></tr><tr><td>38</td><td>Tailspin Toys (Airport Drive, MO)</td><td>Clear</td><td>133</td></tr><tr><td>472</td><td>Wingtip Toys (San Jacinto, CA)</td><td>Clear</td><td>133</td></tr><tr><td>565</td><td>Wingtip Toys (Wapiti, WY)</td><td>Clear</td><td>133</td></tr><tr><td>583</td><td>Wingtip Toys (Knights Landing, CA)</td><td>Clear</td><td>133</td></tr><tr><td>848</td><td>Alvin Bollinger</td><td>Clear</td><td>133</td></tr><tr><td>1011</td><td>Rajeev Sandhu</td><td>Clear</td><td>133</td></tr><tr><td>3</td><td>Tailspin Toys (Peeples Valley, AZ)</td><td>Clear</td><td>132</td></tr><tr><td>531</td><td>Wingtip Toys (Omer, MI)</td><td>Clear</td><td>132</td></tr><tr><td>545</td><td>Wingtip Toys (Jamison, IA)</td><td>Clear</td><td>132</td></tr><tr><td>593</td><td>Wingtip Toys (Cuyamungue, NM)</td><td>Clear</td><td>132</td></tr><tr><td>947</td><td>Svetlana Todorovic</td><td>Clear</td><td>132</td></tr><tr><td>976</td><td>Alinne Matos</td><td>Clear</td><td>132</td></tr><tr><td>982</td><td>Yves Belisle</td><td>Clear</td><td>132</td></tr><tr><td>78</td><td>Tailspin Toys (Sekiu, WA)</td><td>Clear</td><td>131</td></tr><tr><td>79</td><td>Tailspin Toys (Page City, KS)</td><td>Clear</td><td>131</td></tr><tr><td>131</td><td>Tailspin Toys (Kwethluk, AK)</td><td>Clear</td><td>131</td></tr><tr><td>177</td><td>Tailspin Toys (Orrtanna, PA)</td><td>Clear</td><td>131</td></tr><tr><td>195</td><td>Tailspin Toys (L ...

-- %% [markdown]
-- /\* =========================================================
--
-- Q7. Proposition: Show customers with long payment terms (\>=45 days) and their country.
--
-- Join type: INNER JOIN chain (Customers → Cities → States → Countries)
--
-- \========================================================= \*/

-- %%
SELECT c.CustomerID,              -- customer ID
       c.CustomerName,            -- customer name
       c.PaymentDays,             -- payment term length
       co.CountryName             -- country name
FROM Sales.Customers AS c
INNER JOIN Application.Cities AS ci
  ON ci.CityID = c.DeliveryCityID
INNER JOIN Application.StateProvinces AS sp
  ON sp.StateProvinceID = ci.StateProvinceID
INNER JOIN Application.Countries AS co
  ON co.CountryID = sp.CountryID
WHERE c.PaymentDays >= 45         -- filter for long payment terms
ORDER BY c.PaymentDays DESC, c.CustomerID;
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>CustomerID</th><th>CustomerName</th><th>PaymentDays</th><th>CountryName</th></tr></table>

-- %% [markdown]
-- /\* =========================================================
--
-- Q8. Proposition: Create a 5×5 multiplication table by generating values with a CROSS JOIN.
--
-- Join type: CROSS JOIN (Cartesian product)
--
-- \========================================================= \*/

-- %%
SELECT n1.v AS N1,                                  -- first number
       n2.v AS N2,                                  -- second number
       n1.v * n2.v AS Product                       -- multiplication result
FROM (VALUES (1),(2),(3),(4),(5)) AS n1(v)          -- values 1 to 5 as first set
CROSS JOIN (VALUES (1),(2),(3),(4),(5)) AS n2(v)    -- values 1 to 5 as second set
ORDER BY n1.v, n2.v;                                -- order results like a table
-- Out:
-- (25 rows affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>N1</th><th>N2</th><th>Product</th></tr><tr><td>1</td><td>1</td><td>1</td></tr><tr><td>1</td><td>2</td><td>2</td></tr><tr><td>1</td><td>3</td><td>3</td></tr><tr><td>1</td><td>4</td><td>4</td></tr><tr><td>1</td><td>5</td><td>5</td></tr><tr><td>2</td><td>1</td><td>2</td></tr><tr><td>2</td><td>2</td><td>4</td></tr><tr><td>2</td><td>3</td><td>6</td></tr><tr><td>2</td><td>4</td><td>8</td></tr><tr><td>2</td><td>5</td><td>10</td></tr><tr><td>3</td><td>1</td><td>3</td></tr><tr><td>3</td><td>2</td><td>6</td></tr><tr><td>3</td><td>3</td><td>9</td></tr><tr><td>3</td><td>4</td><td>12</td></tr><tr><td>3</td><td>5</td><td>15</td></tr><tr><td>4</td><td>1</td><td>4</td></tr><tr><td>4</td><td>2</td><td>8</td></tr><tr><td>4</td><td>3</td><td>12</td></tr><tr><td>4</td><td>4</td><td>16</td></tr><tr><td>4</td><td>5</td><td>20</td></tr><tr><td>5</td><td>1</td><td>5</td></tr><tr><td>5</td><td>2</td><td>10</td></tr><tr><td>5</td><td>3</td><td>15</td></tr><tr><td>5</td><td>4</td><td>20</td></tr><tr><td>5</td><td>5</td><td>25</td></tr></table>

-- %% [markdown]
-- /\* =========================================================
--
-- Q9. Proposition: List the 20 most expensive stock items and their supplier names.
--
-- Join type: INNER JOIN (StockItems → Suppliers)
--
-- \========================================================= \*/

-- %%
SELECT TOP (20)
       si.StockItemID,                        -- stock item ID
       si.StockItemName,                      -- stock item name
       s.SupplierName,                        -- supplier name
       si.UnitPrice                           -- price of the item
FROM Warehouse.StockItems AS si
INNER JOIN Purchasing.Suppliers AS s
  ON s.SupplierID = si.SupplierID
ORDER BY si.UnitPrice DESC, si.StockItemID;   -- most expensive first
-- Out:
-- (20 rows affected)
-- Total execution time: 00:00:00.015
-- <table><tr><th>StockItemID</th><th>StockItemName</th><th>SupplierName</th><th>UnitPrice</th></tr><tr><td>215</td><td>Air cushion machine (Blue)</td><td>Litware, Inc.</td><td>1899.00</td></tr><tr><td>75</td><td>Ride on big wheel monster truck (Black) 1/12 scale</td><td>Northwind Electric Cars</td><td>345.00</td></tr><tr><td>73</td><td>Ride on vintage American toy coupe (Red) 1/12 scale</td><td>Northwind Electric Cars</td><td>285.00</td></tr><tr><td>74</td><td>Ride on vintage American toy coupe (Black) 1/12 scale</td><td>Northwind Electric Cars</td><td>285.00</td></tr><tr><td>8</td><td>USB food flash drive - dim sum 10 drive variety pack</td><td>The Phone Company</td><td>240.00</td></tr><tr><td>15</td><td>USB food flash drive - dessert 10 drive variety pack</td><td>The Phone Company</td><td>240.00</td></tr><tr><td>174</td><td>Bubblewrap dispenser (Black) 1.5m</td><td>Litware, Inc.</td><td>240.00</td></tr><tr><td>175</td><td>Bubblewrap dispenser (Blue) 1.5m</td><td>Litware, Inc.</td><td>240.00</td></tr><tr><td>176</td><td>Bubblewrap dispenser (Red) 1.5m</td><td>Litware, Inc.</td><td>240.00</td></tr><tr><td>67</td><td>Ride on toy sedan car (Black) 1/12 scale</td><td>Northwind Electric Cars</td><td>230.00</td></tr><tr><td>68</td><td>Ride on toy sedan car (Red) 1/12 scale</td><td>Northwind Electric Cars</td><td>230.00</td></tr><tr><td>69</td><td>Ride on toy sedan car (Blue) 1/12 scale</td><td>Northwind Electric Cars</td><td>230.00</td></tr><tr><td>70</td><td>Ride on toy sedan car (Green) 1/12 scale</td><td>Northwind Electric Cars</td><td>230.00</td></tr><tr><td>71</td><td>Ride on toy sedan car (Yellow) 1/12 scale</td><td>Northwind Electric Cars</td><td>230.00</td></tr><tr><td>72</td><td>Ride on toy sedan car (Pink) 1/12 scale</td><td>Northwind Electric Cars</td><td>230.00</td></tr><tr><td>164</td><td>32 mm Double sided bubble wrap 50m</td><td>Litware, Inc.</td><td>112.00</td></tr><tr><td>161</td><td>20 mm Double sided bubble wrap 50m</td><td>Litware, Inc.</td><td>108.00</td></tr><tr><td>158</td><td>10 mm Double sided bubble wrap 50m</td><td>Litware, Inc.</td><td>105.00</td></tr><tr><td>173</td><td>32 mm Anti static bubble wrap (Blue) 50m</td><td>Litware, Inc.</td><td>105.00</td></tr><tr><td>170</td><td>20 mm Anti static bubble wrap (Blue) 50m</td><td>Litware, Inc.</td><td>102.00</td></tr></table>

-- %% [markdown]
-- /\* =========================================================
--
-- Q10. Proposition: Show the 20 most recent orders with the customer and salesperson names.
--
-- Join type: INNER JOINs (Orders → Customers, Orders → People)
--
-- \========================================================= \*/

-- %%
SELECT TOP (20)
       o.OrderID,                              -- order ID
       o.OrderDate,                            -- date of order
       c.CustomerName,                         -- customer name
       p.FullName AS Salesperson               -- salesperson full name
FROM Sales.Orders AS o
INNER JOIN Sales.Customers AS c
  ON c.CustomerID = o.CustomerID
INNER JOIN Application.People AS p
  ON p.PersonID = o.SalespersonPersonID
ORDER BY o.OrderDate DESC, o.OrderID DESC;     -- most recent first
-- Out:
-- (20 rows affected)
-- Total execution time: 00:00:00.057
-- <table><tr><th>OrderID</th><th>OrderDate</th><th>CustomerName</th><th>Salesperson</th></tr><tr><td>73595</td><td>2016-05-31</td><td>Tailspin Toys (Devault, PA)</td><td>Lily Code</td></tr><tr><td>73594</td><td>2016-05-31</td><td>Wingtip Toys (Shay, PA)</td><td>Archer Lamble</td></tr><tr><td>73593</td><td>2016-05-31</td><td>Wingtip Toys (Chetek, WI)</td><td>Kayla Woodcock</td></tr><tr><td>73592</td><td>2016-05-31</td><td>Emma Van Zant</td><td>Hudson Hollinworth</td></tr><tr><td>73591</td><td>2016-05-31</td><td>Tailspin Toys (Corfu, NY)</td><td>Jack Potter</td></tr><tr><td>73590</td><td>2016-05-31</td><td>Wingtip Toys (Waycross, GA)</td><td>Archer Lamble</td></tr><tr><td>73589</td><td>2016-05-31</td><td>Wingtip Toys (Lytle, TX)</td><td>Hudson Onslow</td></tr><tr><td>73588</td><td>2016-05-31</td><td>Ana Florea</td><td>Amy Trefl</td></tr><tr><td>73587</td><td>2016-05-31</td><td>Nils Kaulins</td><td>Hudson Onslow</td></tr><tr><td>73586</td><td>2016-05-31</td><td>Wingtip Toys (Penns Creek, PA)</td><td>Jack Potter</td></tr><tr><td>73585</td><td>2016-05-31</td><td>Tailspin Toys (Antares, AZ)</td><td>Kayla Woodcock</td></tr><tr><td>73584</td><td>2016-05-31</td><td>Wingtip Toys (Miesville, MN)</td><td>Jack Potter</td></tr><tr><td>73583</td><td>2016-05-31</td><td>Liidia Lepp</td><td>Kayla Woodcock</td></tr><tr><td>73582</td><td>2016-05-31</td><td>Wingtip Toys (Obetz, OH)</td><td>Hudson Onslow</td></tr><tr><td>73581</td><td>2016-05-31</td><td>Taneli Riutta</td><td>Archer Lamble</td></tr><tr><td>73580</td><td>2016-05-31</td><td>Linh Dao</td><td>Hudson Hollinworth</td></tr><tr><td>73579</td><td>2016-05-31</td><td>Sabine Alksne</td><td>Kayla Woodcock</td></tr><tr><td>73578</td><td>2016-05-31</td><td>Nils Kaulins</td><td>Archer Lamble</td></tr><tr><td>73577</td><td>2016-05-31</td><td>Tailspin Toys (Glen Park, NY)</td><td>Jack Potter</td></tr><tr><td>73576</td><td>2016-05-31</td><td>Ana Florea</td><td>Hudson Onslow</td></tr></table>
